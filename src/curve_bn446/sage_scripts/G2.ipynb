# %%
q = 102211695604069718983520304652693874995639508460729604902280098199792736381528662976886082950231100101353700265360419596271313339023463

# %%
K.<a> = GF(q**2, name='a', modulus=x^2 + 1)

# %%
(a+16).is_square()
# Out:
# False

# %%
(a+16).nth_root(3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-e2e07c228cc5> in <module>
# ----> 1 (a+Integer(16)).nth_root(Integer(3))
#
# ~/miniconda3/envs/sage/lib/python3.9/site-packages/sage/rings/finite_rings/element_base.pyx in sage.rings.finite_rings.element_base.FinitePolyExtElement.nth_root (build/cythonized/sage/rings/finite_rings/element_base.c:9726)()
#     744         from sage.rings.integer import Integer
#     745         n = Integer(n)
# --> 746         return self._nth_root_common(n, all, algorithm, cunningham)
#     747
#     748     def pth_power(self, int k = 1):
#
# ~/miniconda3/envs/sage/lib/python3.9/site-packages/sage/rings/finite_rings/element_base.pyx in sage.rings.finite_rings.element_base.FiniteRingElement._nth_root_common (build/cythonized/sage/rings/finite_rings/element_base.c:3505)()
#      70         if self**q1overn != 1:
# ...

# %%
257 / (a+16)
# Out:
# 102211695604069718983520304652693874995639508460729604902280098199792736381528662976886082950231100101353700265360419596271313339023462*a + 16

# %%
X = 2^110 + 2^36 + 1
print(X)
# Out:
# 1298074214633706907132692801781761

# %%
cofactor = (36 * X^4) + (36 * X^3) + (30 * X^2) + 6*X + 1

# %%
def print_repr(x):
    a1 = x % 2^64
    x = x - a1
    x /= 2^64
    a2 = x % 2^64
    x = x - a2
    x /= 2^64
    a3 = x % 2^64
    x = x - a3
    x /= 2^64
    a4 = x % 2^64
    x = x - a4
    x /= 2^64
    a5 = x % 2^64
    x = x - a5
    x /= 2^64
    a6 = x % 2^64
    x = x - a6
    x /= 2^64
    a7 = x
    print("{}u64,".format(a1))
    print("{}u64,".format(a2))
    print("{}u64,".format(a3))
    print("{}u64,".format(a4))
    print("{}u64,".format(a5))
    print("{}u64,".format(a6))
    print("{}u64,".format(a7))
print(cofactor)
print_repr(cofactor)
# Out:
# 102211695604069718983520304652693874995639508460729604902280098199802846361528844466809084151324502007903115563866166482562610972590189
# 21852793602157u64,
# 25543854136582656u64,
# 9727775195308228608u64,
# 104689827840u64,
# 14843406975516u64,
# 10133099161767936u64,
# 2594073385365405696u64,

# %%
r = 102211695604069718983520304652693874995639508460729604902280098199782626401528481486963081749137698194804284966854672709980015705456737

# %%
cofactor_inv = Integer(pow(cofactor, -1, r))
print(cofactor_inv)
# Out:
# 51105847802034859491760152326346976868332800324579441162432910036007228880689248164925884407083870920310630593358164294382371597189209

# %%
E = EllipticCurve(K, [0,0,0,0, 257 / (a+16)])

# %%
# trying to find a simple representation for a point on the curve
G2_generator_y = 4

# %%
E.order()
# Out:
# 

# %%
G2_generator_x = -a

# %%
P = E(G2_generator_x, G2_generator_y)
P
# Out:
# (102211695604069718983520304652693874995639508460729604902280098199792736381528662976886082950231100101353700265360419596271313339023462*a : 4 : 1)

# %%
factor(r - 1)
# Out:
# 2^5 * 3^2 * 11 * 79 * 113 * 137 * 619 * 1777 * 8243 * 14783 * 43037 * 25781083 * 2420302828357 * 73290976649952054871816052716880938545334447882707288509816857838279869068051439772747

# %%
Integer(((r - 1) / 2)) * P
# Out:
